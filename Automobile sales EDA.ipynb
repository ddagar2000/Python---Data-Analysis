# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings("ignore")

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[272], line 5
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 warnings.filterwarnings("ignore")
#       7 get_ipython().run_line_magic('matplotlib', 'inline')
#
# NameError: name 'warnings' is not defined

# %%
df = pd.read_csv('/Users/dhruvidagar/Desktop/DUCAT/Auto Sales data.csv')
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0  24/02/2018                   828  Shipped  Motorcycles    95    S10_1678
# 1  07/05/2018                   757  Shipped  Motorcycles    95    S10_1678
# 2  01/07/2018                   703  Shipped  Motorcycles    95    S10_1678
# 3  25/08/2018                   649  Shipped  Motorcycles    95    S10_1678
# 4  28/10/2018                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   object
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESSLINE1          2747 non-null   object
#  14  CITY                  2747 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER             0
# QUANTITYORDERED         0
# PRICEEACH               0
# ORDERLINENUMBER         0
# SALES                   0
# ORDERDATE               0
# DAYS_SINCE_LASTORDER    0
# STATUS                  0
# PRODUCTLINE             0
# MSRP                    0
# PRODUCTCODE             0
# CUSTOMERNAME            0
# PHONE                   0
# ADDRESSLINE1            0
# CITY                    0
# POSTALCODE              0
# COUNTRY                 0
# CONTACTLASTNAME         0
# CONTACTFIRSTNAME        0
# DEALSIZE                0
# dtype: int64

# %%
df_copy[df_copy.duplicated('POSTALCODE')].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[276], line 1
# ----> 1 df_copy[df_copy.duplicated('POSTALCODE')].shape
#
# NameError: name 'df_copy' is not defined

# %%
df_copy[df_copy.duplicated('ORDERNUMBER')].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[277], line 1
# ----> 1 df_copy[df_copy.duplicated('ORDERNUMBER')].shape
#
# NameError: name 'df_copy' is not defined

# %%
df['PHONE'] = df['PHONE'].str.replace(r'\D', '', regex=True)

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0  24/02/2018                   828  Shipped  Motorcycles    95    S10_1678
# 1  07/05/2018                   757  Shipped  Motorcycles    95    S10_1678
# 2  01/07/2018                   703  Shipped  Motorcycles    95    S10_1678
# 3  25/08/2018                   649  Shipped  Motorcycles    95    S10_1678
# 4  28/10/2018                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME        PHONE                   ADDRESSLINE1  \
# ...

# %%
df['ORDERDATE'] = pd.to_datetime(df['ORDERDATE'], dayfirst=True)

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#    ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0 2018-02-24                   828  Shipped  Motorcycles    95    S10_1678
# 1 2018-05-07                   757  Shipped  Motorcycles    95    S10_1678
# 2 2018-07-01                   703  Shipped  Motorcycles    95    S10_1678
# 3 2018-08-25                   649  Shipped  Motorcycles    95    S10_1678
# 4 2018-10-28                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME        PHONE                   ADDRESSLINE1  \
# ...

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2747.000000      2747.000000  2747.000000      2747.000000
# mean   10259.761558        35.103021   101.098952         6.491081
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10181.000000        27.000000    68.745000         3.000000
# 50%    10264.000000        35.000000    95.550000         6.000000
# 75%    10334.500000        43.000000   127.100000         9.000000
# max    10425.000000        97.000000   252.870000        18.000000
# std       91.877521         9.762135    42.042549         4.230544
#
#               SALES                      ORDERDATE  DAYS_SINCE_LASTORDER  \
# count   2747.000000                           2747           2747.000000
# mean    3553.047583  2019-05-13 21:56:17.211503360           1757.085912
# min      482.130000            2018-01-06 00:00:00             42.000000
# ...

# %%
df['STATUS'] = df['STATUS'].str.strip().str.title()

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#    ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0 2018-02-24                   828  Shipped  Motorcycles    95    S10_1678
# 1 2018-05-07                   757  Shipped  Motorcycles    95    S10_1678
# 2 2018-07-01                   703  Shipped  Motorcycles    95    S10_1678
# 3 2018-08-25                   649  Shipped  Motorcycles    95    S10_1678
# 4 2018-10-28                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME        PHONE                   ADDRESSLINE1  \
# ...

# %%
df['POSTALCODE'] = df['POSTALCODE'].fillna("Unknown")

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#    ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0 2018-02-24                   828  Shipped  Motorcycles    95    S10_1678
# 1 2018-05-07                   757  Shipped  Motorcycles    95    S10_1678
# 2 2018-07-01                   703  Shipped  Motorcycles    95    S10_1678
# 3 2018-08-25                   649  Shipped  Motorcycles    95    S10_1678
# 4 2018-10-28                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME        PHONE                   ADDRESSLINE1  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df['SALES'] != df['PRICEEACH'] * df['QUANTITYORDERED']]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# 7           10211               41     114.84               14  4708.44
# ...           ...              ...        ...              ...      ...
# 2733        10248               23      65.52                9  1506.96
# 2734        10261               29      50.78                7  1472.62
# 2740        10327               37      86.74                4  3209.38
# 2743        10373               29     137.19                1  3978.51
# 2746        10414               47      65.52                9  3079.44
#
#       ORDERDATE  DAYS_SINCE_LASTORDER     STATUS  PRODUCTLINE  MSRP  \
# ...

# %%
df['PRODUCTLINE'] = df['PRODUCTLINE'].str.strip().str.title()

# %%
df['DEALSIZE'].value_counts()
# Out:
# DEALSIZE
# Medium    1349
# Small     1246
# Large      152
# Name: count, dtype: int64

# %%
df['YEAR'] = df['ORDERDATE'].dt.year
df['MONTH'] = df['ORDERDATE'].dt.month

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#    ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP  ...  \
# 0 2018-02-24                   828  Shipped  Motorcycles    95  ...
# 1 2018-05-07                   757  Shipped  Motorcycles    95  ...
# 2 2018-07-01                   703  Shipped  Motorcycles    95  ...
# 3 2018-08-25                   649  Shipped  Motorcycles    95  ...
# 4 2018-10-28                   586  Shipped  Motorcycles    95  ...
#
#          PHONE                   ADDRESSLINE1        CITY POSTALCODE COUNTRY  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   datetime64[ns]
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESSLINE1          2747 non-null   object
#  14  CITY                  2747 non-null   object
# ...

# %%
df['STATUS'].unique()
# Out:
# array(['Shipped', 'Disputed', 'In Process', 'Cancelled', 'On Hold',
#        'Resolved'], dtype=object)

# %%
df_copy['ORDERNUMBER'].value_counts().plot.pie(y=df_copy['ORDERNUMBER'],figsize=(10,40),autopct='%1.1f')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[295], line 1
# ----> 1 df_copy['ORDERNUMBER'].value_counts().plot.pie(y=df_copy['ORDERNUMBER'],figsize=(10,40),autopct='%1.1f')
#
# NameError: name 'df_copy' is not defined

# %%
df['COUNTRY'].value_counts()
# Out:
# COUNTRY
# USA            928
# Spain          342
# France         314
# Australia      185
# UK             144
# Italy          113
# Finland         92
# Norway          85
# Singapore       79
# Canada          70
# Denmark         63
# Germany         62
# Sweden          57
# Austria         55
# Japan           52
# Belgium         33
# Switzerland     31
# Philippines     26
# Ireland         16
# Name: count, dtype: int64

# %%
COUNTRY = df['COUNTRY'].value_counts().reset_index()
COUNTRY.columns = ['country', 'count']

# %%
## Top 10 app
plt.figure(figsize=(15,6))
sns.barplot(x=COUNTRY['country'][:10], y=COUNTRY['count'][:10], palette='hls')
plt.title('Top 10 Countries')
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/pr/fhbf6nxn165_2v51jljjyhlm0000gn/T/ipykernel_32156/1093135408.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=COUNTRY['country'][:10], y=COUNTRY['count'][:10], palette='hls')

# %%
df['CITY'].value_counts()
# Out:
# CITY
# Madrid        304
# San Rafael    180
# NYC           152
# Singapore      79
# Paris          70
#              ...
# Brisbane       15
# Sevilla        15
# Munich         14
# Burbank        13
# Charleroi       8
# Name: count, Length: 71, dtype: int64

# %%
CITY = df['CITY'].value_counts().reset_index()
CITY.columns = ['city', 'count']

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=CITY['city'][:10], y=CITY['count'][:10], palette='hls')
plt.title('Top 10 Countries')
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/pr/fhbf6nxn165_2v51jljjyhlm0000gn/T/ipykernel_32156/3347432534.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=CITY['city'][:10], y=CITY['count'][:10], palette='hls')

# %%
df_copy['PRODUCTLINE'].value_counts().plot.pie(y = df_copy['PRODUCTLINE'],figsize=(10,40),autopct='%1.1f')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[302], line 1
# ----> 1 df_copy['PRODUCTLINE'].value_counts().plot.pie(y = df_copy['PRODUCTLINE'],figsize=(10,40),autopct='%1.1f')
#
# NameError: name 'df_copy' is not defined

# %%
df['ORDERDATE'].value_counts()
# Out:
# ORDERDATE
# 2018-11-14    38
# 2019-11-24    35
# 2018-11-12    34
# 2019-11-17    32
# 2019-11-04    29
#               ..
# 2020-02-08     1
# 2018-10-10     1
# 2019-02-02     1
# 2019-08-28     1
# 2018-04-21     1
# Name: count, Length: 246, dtype: int64

# %%
df['PRODUCTLINE'].value_counts()
# Out:
# PRODUCTLINE
# Classic Cars        949
# Vintage Cars        579
# Motorcycles         313
# Planes              304
# Trucks And Buses    295
# Ships               230
# Trains               77
# Name: count, dtype: int64

# %%
ORDERDATE = df['ORDERDATE'].value_counts().reset_index()
ORDERDATE.columns = ['orderdate', 'count']

# %%
PRODUCTLINE = df['PRODUCTLINE'].value_counts().reset_index()
PRODUCTLINE.columns = ['productline', 'count']

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=ORDERDATE['orderdate'][:50], y=ORDERDATE['orderdate'][:50], palette='hls')
plt.title('MOST products sold count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/pr/fhbf6nxn165_2v51jljjyhlm0000gn/T/ipykernel_32156/4265890245.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ORDERDATE['orderdate'][:50], y=ORDERDATE['orderdate'][:50], palette='hls')

# %%
df['YEAR'].value_counts()
# Out:
# YEAR
# 2019    1329
# 2018     953
# 2020     465
# Name: count, dtype: int64

# %%
YEAR = df['YEAR'].value_counts().reset_index()
YEAR.columns = ['year', 'count']

# %%
df['YEAR'].unique()
# Out:
# array([2018, 2019, 2020], dtype=int32)

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=PRODUCTLINE['productline'][:50], y=YEAR['year'][:50], palette='hls')
plt.title('MOST products sold count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/pr/fhbf6nxn165_2v51jljjyhlm0000gn/T/ipykernel_32156/2382314313.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=PRODUCTLINE['productline'][:50], y=YEAR['year'][:50], palette='hls')

# %%
df['PRODUCTLINE'].unique()
# Out:
# array(['Motorcycles', 'Classic Cars', 'Trucks And Buses', 'Vintage Cars',
#        'Planes', 'Ships', 'Trains'], dtype=object)

# %%
df_clean = df.copy()

# %%
df_clean['ORDERDATE'] = pd.to_datetime(df_clean['ORDERDATE'])

# %%
for col in df_clean.select_dtypes(include='object').columns:
    df_clean[col] = df_clean[col].str.strip()

# %%
### Feature  Engineering

# %%
df_clean['YEAR'] = df_clean['ORDERDATE'].dt.year
df_clean['MONTH'] = df_clean['ORDERDATE'].dt.month
df_clean['MONTH_NAME'] = df_clean['ORDERDATE'].dt.month_name()
df_clean['DAYOFWEEK'] = df_clean['ORDERDATE'].dt.day_name()

# %%
df_clean[['ORDERDATE', 'YEAR', 'MONTH', 'MONTH_NAME', 'DAYOFWEEK']].head()
# Out:
#    ORDERDATE  YEAR  MONTH MONTH_NAME DAYOFWEEK
# 0 2018-02-24  2018      2   February  Saturday
# 1 2018-05-07  2018      5        May    Monday
# 2 2018-07-01  2018      7       July    Sunday
# 3 2018-08-25  2018      8     August  Saturday
# 4 2018-10-28  2018     10    October    Sunday

# %%
### UNIVARIATE EDA
### NUMERICAL COLUMN SUMMARY

# %%
num_cols = ['QUANTITYORDERED', 'PRICEEACH', 'SALES', 'DAYS_SINCE_LASTORDER', 'MSRP',
            'ORDERLINENUMBER', 'YEAR', 'MONTH']

df_clean[num_cols].describe().T
# Out:
#                        count         mean          std      min       25%  \
# QUANTITYORDERED       2747.0    35.103021     9.762135     6.00    27.000
# PRICEEACH             2747.0   101.098952    42.042549    26.88    68.745
# SALES                 2747.0  3553.047583  1838.953901   482.13  2204.350
# DAYS_SINCE_LASTORDER  2747.0  1757.085912   819.280576    42.00  1077.000
# MSRP                  2747.0   100.691664    40.114802    33.00    68.000
# ORDERLINENUMBER       2747.0     6.491081     4.230544     1.00     3.000
# YEAR                  2747.0  2018.822352     0.696288  2018.00  2018.000
# MONTH                 2747.0     7.083364     3.641826     1.00     4.000
#
#                           50%       75%       max
# QUANTITYORDERED         35.00    43.000     97.00
# PRICEEACH               95.55   127.100    252.87
# SALES                 3184.80  4503.095  14082.80
# DAYS_SINCE_LASTORDER  1761.00  2436.500   3562.00
# ...

# %%
### Distribution of Sales

# %%
plt.figure(figsize=(10,6))
df_clean['SALES'].hist(bins=30)
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Boxplot of SALES (OUTLIERS)

# %%
plt.figure(figsize=(6,6))
plt.boxplot(df_clean['SALES'])
plt.title('Boxplot of Sales')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ## Observations
# ## Sales distribution is right skewed

# %%
cat_cols = df_clean.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['STATUS', 'PRODUCTLINE', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'CITY', 'POSTALCODE', 'COUNTRY', 'CONTACTLASTNAME',
#        'CONTACTFIRSTNAME', 'DEALSIZE', 'MONTH_NAME', 'DAYOFWEEK'],
#       dtype='object')

# %%
# Status distribution
df_clean['STATUS'].value_counts()
# Out:
# STATUS
# Shipped       2541
# Cancelled       60
# Resolved        47
# On Hold         44
# In Process      41
# Disputed        14
# Name: count, dtype: int64

# %%
#### PRoduct line distribution
df_clean['PRODUCTLINE'].value_counts()
# Out:
# PRODUCTLINE
# Classic Cars        949
# Vintage Cars        579
# Motorcycles         313
# Planes              304
# Trucks And Buses    295
# Ships               230
# Trains               77
# Name: count, dtype: int64

# %%
#Deal size distribution
df_clean['DEALSIZE'].value_counts()
# Out:
# DEALSIZE
# Medium    1349
# Small     1246
# Large      152
# Name: count, dtype: int64

# %% [markdown]
# ### Observation
# * Most orders are shipped followed by smaller counts of cancelled, on hold, in process etc
# * Most common product line: Classic cars, then vintage cars.
# * Majority of deals are medium and small , large deals are rare

# %%
plt.figure(figsize=(10,6))
df_clean.groupby('PRODUCTLINE')['SALES'].sum().sort_values(ascending=False).plot(kind='bar')
plt.title('Total Sales by Product Line')
plt.ylabel('Total Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insights
# * Classic Cars contribute the highest total sales.
# *  Vntage cars are 2nd
# *  Trains, Ships contribute less comparatively
# *  Average order value is also higher for classic cars and tricks/buses

# %%
# Sales by Deal Size
sales_by_dealsize=  (
    df_clean.groupby('DEALSIZE')['SALES']
    .agg(['count','sum', 'mean'])
)
sales_by_dealsize
# Out:
#           count         sum         mean
# DEALSIZE
# Large       152  1258956.40  8282.607895
# Medium     1349  5931231.47  4396.761653
# Small      1246  2570033.84  2062.627480

# %% [markdown]
# ### Insights
# * Large deals have the highest average sales per order(~8k+), but they are few in count.
# * Medium deals dominate both in count and total revenue.

# %%
# Sales by Order Status
sales_by_status = (
    df_clean.groupby('STATUS')['SALES']
    .agg(['count','sum', 'mean'])
)
sales_by_status
# Out:
#             count         sum         mean
# STATUS
# Cancelled      60   194487.48  3241.458000
# Disputed       14    72212.86  5158.061429
# In Process     41   144729.96  3529.999024
# On Hold        44   178979.19  4067.708864
# Resolved       47   150718.28  3206.771915
# Shipped      2541  9019093.94  3549.426974

# %% [markdown]
# ### Insights
# * Most revenue comes from shipped order(obvious but confirmed).
# * Cancelled and DIsputed orders exist but thier revenue is much smller.
# * The average sales value for Disputed rders is actually quite high.

# %%
#Sales by country(Top 10)
country_sales = (
    df_clean.groupby('COUNTRY')['SALES']
    .sum()
    .sort_values(ascending=False)
    .head(10)
)
country_sales
# Out:
# COUNTRY
# USA          3355575.69
# Spain        1215686.92
# France       1110916.52
# Australia     630623.10
# UK            478880.46
# Italy         374674.31
# Finland       329581.91
# Norway        307463.70
# Singapore     288488.41
# Denmark       245637.15
# Name: SALES, dtype: float64

# %% [markdown]
# plt.figure(figsize=(10,6))
# country_sales.plot(kind='bar')
# plt.title('Top 10 Countries by Total Sales')
# plt.ylabel('Total Sales')
# plt.xticks(rotation = 45, ha= 'right')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### Insights
#
# * USA is the biggest market in terms of total sales
# * Followed by Spain, France, Australia, UK.
# * These are key geographics for business focus.

# %%
# Times series : monthly sales trend

# Group by yeare-month period
df_monthly = df_clean.groupby(df_clean['ORDERDATE'].dt.to_period('M'))['SALES'].sum()

#Convert PeriodIndex to Timestamp for plotting
df_monthly.index = df_monthly.index.to_timestamp()

plt.figure(figsize=(12,6))
plt.plot(df_monthly.index, df_monthly.values)
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insight
#
# * You'll see peaks and drops in certain months.
# * Helps Identify seasonality(e.g. some months with consistently higher sales)

# %%
# Sales by day of week
sales_by_day =(
    df_clean.groupby('DAYOFWEEK')['SALES']
    .sum()
    .reindex(['Monday','Tuesday','Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
)

sales_by_day
# Out:
# DAYOFWEEK
# Monday       1827922.60
# Tuesday      1895468.79
# Wednesday    1374952.04
# Thursday      151979.05
# Friday       1046541.96
# Saturday     1288235.79
# Sunday       2175121.48
# Name: SALES, dtype: float64

# %%
plt.figure(figsize=(8,5))
sales_by_day.plot(kind='bar')
plt.title('Total Sales by Day of Week')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insight
# * Shows which weekdays have higher order valumes/values.
# * Useful for planning manpower, logistics etc.

# %% [markdown]
# ### Correlation Analysis

# %%
#We'll see how numeric variables relate to each other

corr_cols = ['QUANTITYORDERED','PRICEEACH', 'SALES', 
             'DAYS_SINCE_LASTORDER','MSRP',
             'ORDERLINENUMBER','YEAR','MONTH']

corr = df_clean[corr_cols].corr()
corr
# Out:
#                       QUANTITYORDERED  PRICEEACH     SALES  \
# QUANTITYORDERED              1.000000   0.010161  0.553359
# PRICEEACH                    0.010161   1.000000  0.808287
# SALES                        0.553359   0.808287  1.000000
# DAYS_SINCE_LASTORDER        -0.021923  -0.397091 -0.334274
# MSRP                         0.020551   0.778393  0.634849
# ORDERLINENUMBER             -0.016295  -0.052646 -0.057414
# YEAR                         0.070520  -0.012493  0.033604
# MONTH                       -0.037926   0.017535 -0.010200
#
#                       DAYS_SINCE_LASTORDER      MSRP  ORDERLINENUMBER  \
# QUANTITYORDERED                  -0.021923  0.020551        -0.016295
# PRICEEACH                        -0.397091  0.778393        -0.052646
# SALES                            -0.334274  0.634849        -0.057414
# DAYS_SINCE_LASTORDER              1.000000 -0.524285         0.046615
# MSRP                             -0.524285  1.000000        -0.020956
# ...

# %%
plt.figure(figsize=(8,6))
plt.imshow(corr, interpolation='nearest')
plt.xticks(range(len(corr_cols)),corr_cols,rotation=45,ha = 'right')
plt.yticks(range(len(corr_cols)),corr_cols)
plt.colorbar(label='Correlation')
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Key Correlations
#
# * Sales is strongly positively correlated with Priceeach and MSRP.
# * Sales is moderately correlated with Quantityordered
# * DAY_SINCE_LASTORDER is negatively correlated with MSRP and PRICEEACH - high priced items may have more recent orders.
# * Year and Month correlations are small but can show seasonal/year trends

# %% [markdown]
# #### Sales Buckets (Low/Medium/High)
# * We'll use use quantities of sales to define buckets

# %%
# Check quantities of slaes

df_clean['SALES'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    2204.350
# 0.50    3184.800
# 0.75    4503.095
# Name: SALES, dtype: float64

# %%
# We'll split into 3 buckets
# Define thresholds using quantiles
q1 = df_clean['SALES'].quantile(0.33)
q2 = df_clean['SALES'].quantile(0.66)

q1,q2
# Out:
# (np.float64(2513.3034000000002), np.float64(3910.8756000000003))

# %%
def sales_bucket(x):
    if x <= q1:
        return 'Low'
    elif x<= q2:
        return 'Medium'
    else:
        return 'High'

df_clean['SALES_BUCKET'] = df_clean['SALES'].apply(sales_bucket)

df_clean['SALES_BUCKET'].value_counts()
# Out:
# SALES_BUCKET
# High      934
# Low       907
# Medium    906
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
df_clean['SALES_BUCKET'].value_counts().plot(kind='bar')
plt.title('Count of Orders by Sales Bucket')
plt.xlabel('Sales Bucket')
plt.ylabel('Number of Orders')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Country Buckets (Top Markets vs others)
#
# Lets group countries into:
# * Top markets (highest total sales)
# * others

# %%
# Total sales by country
country_sales = (
    df_clean.groupby('COUNTRY')['SALES']
    .sum()
    .sort_values(ascending=False)

)

country_sales.head(10)
# Out:
# COUNTRY
# USA          3355575.69
# Spain        1215686.92
# France       1110916.52
# Australia     630623.10
# UK            478880.46
# Italy         374674.31
# Finland       329581.91
# Norway        307463.70
# Singapore     288488.41
# Denmark       245637.15
# Name: SALES, dtype: float64

# %%
# Suppose we choose top 5 as key markets
top_countries = country_sales.head(5).index.tolist()
top_countries
# Out:
# ['USA', 'Spain', 'France', 'Australia', 'UK']

# %%
def country_bucket(x):
    if x in top_countries:
        return 'Top Market'
    else:
        return'Other Market'

df_clean['COUNTRY_BUCKET'] = df_clean['COUNTRY'].apply(country_bucket)

df_clean['COUNTRY_BUCKET'].value_counts()
# Out:
# COUNTRY_BUCKET
# Top Market      1913
# Other Market     834
# Name: count, dtype: int64

# %%
df_clean['DAYS_SINCE_LASTORDER'].describe()
# Out:
# count    2747.000000
# mean     1757.085912
# std       819.280576
# min        42.000000
# 25%      1077.000000
# 50%      1761.000000
# 75%      2436.500000
# max      3562.000000
# Name: DAYS_SINCE_LASTORDER, dtype: float64

# %%
# Price threshold
def recency_bucket(days):
    if days <= 365:
        return 'Recent'       #ordered within ~1 year
    elif days <= 2*365:
        return 'warm'          # 1-2 years
    else: 
        return 'Dormat'         # > 2 years

df_clean['RECENCY_BUCKET'] = df_clean['DAYS_SINCE_LASTORDER'].apply(recency_bucket)

df_clean['RECENCY_BUCKET'].value_counts()
# Out:
# RECENCY_BUCKET
# Dormat    2398
# warm       262
# Recent      87
# Name: count, dtype: int64

# %% [markdown]
# * Now you can quickly see how many orders come from recently-active customers vs old ones.

# %% [markdown]
# ### Customer-level aggregates features
#
# We'll create features at customer level and merge them back:
#
# * CUST_TOTAL_SALES - total revenue from that customer
# * CUST_NUM_ORDERS - number of orders
# * CUST_AVG_SALES - average order value

# %%
cust_group = df_clean.groupby('CUSTOMERNAME')['SALES'].agg(
    CUST_TOTAL_SALES = 'sum',
    CUST_NUM_ORDERS = 'count',
    CUST_AVG_SALES = 'mean'

)

cust_group.head()
# Out:
#                          CUST_TOTAL_SALES  CUST_NUM_ORDERS  CUST_AVG_SALES
# CUSTOMERNAME
# AV Stores, Co.                  157807.81               51     3094.270784
# Alpha Cognac                     70488.44               20     3524.422000
# Amica Models & Co.               94117.26               26     3619.894615
# Anna's Decorations, Ltd         153996.13               46     3347.741957
# Atelier graphique                24179.96                7     3454.280000

# %%
cust_group = df_clean.groupby('CUSTOMERNAME')['SALES'].agg(
    CUST_TOTAL_SALES = 'sum',
    CUST_NUM_ORDERS = 'count',
    CUST_AVG_SALES = 'mean'

)

cust_group.head()
# Out:
#                          CUST_TOTAL_SALES  CUST_NUM_ORDERS  CUST_AVG_SALES
# CUSTOMERNAME
# AV Stores, Co.                  157807.81               51     3094.270784
# Alpha Cognac                     70488.44               20     3524.422000
# Amica Models & Co.               94117.26               26     3619.894615
# Anna's Decorations, Ltd         153996.13               46     3347.741957
# Atelier graphique                24179.96                7     3454.280000

# %%
# Now merge back to each row
df_clean = df_clean.merge(cust_group, on='CUSTOMERNAME', how = 'left')

df_clean[['CUSTOMERNAME', 'SALES', 'CUST_TOTAL_SALES',
          'CUST_NUM_ORDERS', 'CUST_AVG_SALES']].head()
# Out:
#            CUSTOMERNAME    SALES  CUST_TOTAL_SALES  CUST_NUM_ORDERS  \
# 0     Land of Toys Inc.  2871.00         164069.44               49
# 1    Reims Collectables  2765.90         135042.94               41
# 2       Lyon Souveniers  3884.34          78570.34               20
# 3     Toys4GrownUps.com  3746.70         104561.96               30
# 4  Technics Stores Inc.  3479.76         120783.07               34
#
#    CUST_AVG_SALES
# 0     3348.355918
# 1     3293.730244
# 2     3928.517000
# 3     3485.398667
# 4     3552.443235

# %%
# you can bucket the customer

def customer_value_bucket(x):
    if x< df_clean['CUST_TOTAL_SALES'].quantile(0.33):
        return 'Low Value Customer'
    elif x< df_clean['CUST_TOTAL_SALES'].quantile(0.66):
        return 'Medium Value Customer'
    else:
        return 'High Value Customer'

df_clean['CUSTOMER_VALUE_SEGMENT'] = df_clean['CUST_TOTAL_SALES'].apply(customer_value_bucket)

df_clean['CUSTOMER_VALUE_SEGMENT'].value_counts()
# Out:
# CUSTOMER_VALUE_SEGMENT
# High Value Customer      946
# Medium Value Customer    917
# Low Value Customer       884
# Name: count, dtype: int64

# %%
df_clean['DISCOUNT_AMT'] = df_clean['MSRP'] - df_clean['PRICEEACH']
df_clean['DISCOUNT_PCT'] = df_clean['DISCOUNT_AMT']/ df_clean['MSRP']

df_clean[['MSRP', 'PRICEEACH', 'DISCOUNT_AMT', 'DISCOUNT_PCT']].head()
# Out:
#    MSRP  PRICEEACH  DISCOUNT_AMT  DISCOUNT_PCT
# 0    95      95.70         -0.70     -0.007368
# 1    95      81.35         13.65      0.143684
# 2    95      94.74          0.26      0.002737
# 3    95      83.26         11.74      0.123579
# 4    95      96.66         -1.66     -0.017474

# %%
def discount_bucket(p):
    if p <= 0.05:
        return 'No / Low Discount'
    elif p<= 0.20:
        return 'Moderate Discount'
    else:
        return 'High Discount'

df_clean['DISCOUNT_BUCKET'] = df_clean['DISCOUNT_PCT'].apply(discount_bucket)

df_clean['DISCOUNT_BUCKET'].value_counts()
# Out:
# DISCOUNT_BUCKET
# No / Low Discount    1684
# Moderate Discount     905
# High Discount         158
# Name: count, dtype: int64

# %%
deal_map = {
    'Small':1,
    'Medium':2,
    'Large':3

}

df_clean['DEALSIZE_ENC'] = df_clean['DEALSIZE'].map(deal_map)

df_clean[['DEALSIZE', 'DEALSIZE_ENC']].head()
# Out:
#   DEALSIZE  DEALSIZE_ENC
# 0    Small             1
# 1    Small             1
# 2   Medium             2
# 3   Medium             2
# 4   Medium             2

# %%
df_clean.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'DAYS_SINCE_LASTORDER', 'STATUS', 'PRODUCTLINE',
#        'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'CITY',
#        'POSTALCODE', 'COUNTRY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE', 'YEAR', 'MONTH', 'MONTH_NAME', 'DAYOFWEEK', 'SALES_BUCKET',
#        'COUNTRY_BUCKET', 'RECENCY_BUCKET', 'CUST_TOTAL_SALES',
#        'CUST_NUM_ORDERS', 'CUST_AVG_SALES', 'CUSTOMER_VALUE_SEGMENT',
#        'DISCOUNT_AMT', 'DISCOUNT_PCT', 'DISCOUNT_BUCKET', 'DEALSIZE_ENC'],
#       dtype='object')

# %%
df_clean.to_csv("Auto_Sales_data_FE.csv", index = False)

# %% [markdown]
# ### SALES_BUCKET VS DISCOUNT_BUCKET
#
# We want to see how disocunt levels relate to order value

# %%
# relationship between Sales bucket and Discount Bucket

pd.crosstab(df_clean['DISCOUNT_BUCKET'], df_clean['SALES_BUCKET'])
# Out:
# SALES_BUCKET       High  Low  Medium
# DISCOUNT_BUCKET
# High Discount        15   92      51
# Moderate Discount   238  374     293
# No / Low Discount   681  441     562

# %%
plt.figure(figsize=(8,5))
pd.crosstab(df_clean['DISCOUNT_BUCKET'],df_clean['SALES_BUCKET']).plot(
    kind = 'bar',
    stacked = True,
    figsize = (8,5)

)
plt.title('Sales Bucket vs Discount Bucket')
plt.xlabel('Discount Bucket')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Average sales by Discount bucket

# %%
# Average sales for each discount bucket

avg_sales_discount = df_clean.groupby('DISCOUNT_BUCKET')['SALES'].mean().sort_values(ascending=False)
avg_sales_discount
# Out:
# DISCOUNT_BUCKET
# No / Low Discount    3861.731657
# Moderate Discount    3180.109514
# High Discount        2399.155000
# Name: SALES, dtype: float64

# %%
plt.figure(figsize=(6,4))
avg_sales_discount.plot(kind='bar')
plt.title('Average sales by discount bucket')
plt.xlabel('Discount Bucket')
plt.ylabel('Average Sales')
plt.xticks(rotation=45, ha = 'right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Country bucket vs total customer sales
# * we want country - level revenue based on customer-level totals

# %%
# prepare unique customer-level data to avaoid double counting
cust_unique = df_clean[['CUSTOMERNAME', 'COUNTRY_BUCKET','CUST_TOTAL_SALES']].drop_duplicates(subset = 'CUSTOMERNAME')

cust_sales_country_bucket = (
    cust_unique.groupby('COUNTRY_BUCKET')['CUST_TOTAL_SALES']
    .sum()
    .sort_values(ascending = False)

)
cust_sales_country_bucket
# Out:
# COUNTRY_BUCKET
# Top Market      6791682.69
# Other Market    2968539.02
# Name: CUST_TOTAL_SALES, dtype: float64

# %%
plt.figure(figsize=(6,4))
cust_sales_country_bucket.plot(kind='bar')
plt.title('Total customer Revenue by country bucket')
plt.xlabel('Country Bucket')
plt.ylabel('Total Customer Sales')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### CUSTOMER_VALUE_SEGMENT VS NUMBER OF CUSTOMERS

# %%
# CUSTOMER VALUE SEGMENTS DISTRIBUTION  (unique customers only)

cust_segment = (
    cust.unique.groupby('CUSTOMERNAME')['CUST_TOTAL_SALES']
    .first()
    .reset_index()

)

cust_segment['CUSTOMER_VALUE_SEGMENT']=cust_segment['CUST_TOTAL_SALES'].apply(customer_value_bucket)

cust_segment['CUSTOMER_VALUE_SEGMENT'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[361], line 4
#       1 # CUSTOMER VALUE SEGMENTS DISTRIBUTION  (unique customers only)
#       3 cust_segment = (
# ----> 4     cust.unique.groupby('CUSTOMERNAME')['CUST_TOTAL_SALES']
#       5     .first()
#       6     .reset_index()
#       7
#       8 )
#      10 cust_segment['CUSTOMER_VALUE_SEGMENT']=cust_segment['CUST_TOTAL_SALES'].apply(customer_value_bucket)
#      12 cust_segment['CUSTOMER_VALUE_SEGMENT'].value_counts()
#
# NameError: name 'cust' is not defined

# %%
plt.figure(figsize=(6,4))
cust_segment['CUSTOMER_VALUE_SEGMENT'].value_counts().plot(kind='bar')
plt.title('Number of customers by value segment')
plt.xlabel('Customer Value Segment')
plt.ylabel('Number of Customers')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[362], line 2
#       1 plt.figure(figsize=(6,4))
# ----> 2 cust_segment['CUSTOMER_VALUE_SEGMENT'].value_counts().plot(kind='bar')
#       3 plt.title('Number of customers by value segment')
#       4 plt.xlabel('Customer Value Segment')
#
# NameError: name 'cust_segment' is not defined

# %% [markdown]
# ### Observation:
# *how many high value, medium value, and low value customers you have.

# %% [markdown]
# ### RECENT_BUCkET vs TOTAL SALES

# %%
# TOTAL SALES BY RECENT BUCKET

sales_by_recency = (
    df_clean.groupby('RECENCY_BUCKET')['SALES']
    .sum()
    .sort_values(ascending=False)

)
sales_by_recency
# Out:
# RECENCY_BUCKET
# Dormat    8119852.03
# warm      1231387.38
# Recent     408982.30
# Name: SALES, dtype: float64

# %%
plt.figure(figsize=(6,4))
sales_by_recency.plot(kind='bar')
plt.title('Total Sales by customers recency bucket')
plt.xlabel('recency bucket')
plt.ylabel('Total Sales')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
