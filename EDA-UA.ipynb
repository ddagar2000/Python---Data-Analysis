# %% [markdown]
# # Univariate Analysis
#
# refers to the analysis of a single variable(feature) in a dataset. The purpose is to understand the distirbution, central tendency, and spread of the data for that particular variable.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"/Users/dhruvidagar/Downloads/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 749          750         0       3            Connaghton, Mr. Michael    male
# 773          774         0       3                    Elias, Mr. Dibo    male
# 208          209         1       3          Carr, Miss. Helen "Ellen"  female
# 444          445         1       3  Johannesen-Bratthammer, Mr. Bernt    male
# 452          453         0       1    Foreman, Mr. Benjamin Laventall    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 749  31.0      0      0  335097   7.7500   NaN        Q
# 773   NaN      0      0    2674   7.2250   NaN        C
# 208  16.0      0      0  367231   7.7500   NaN        Q
# 444   NaN      0      0   65306   8.1125   NaN        S
# 452  30.0      0      0  113051  27.7500  C111        C

# %%
import seaborn as sns

# %%
sns.countplot(x=df['Survived'])
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Pclass'])
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Sex'])
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Embarked'])
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='pie',autopct = '%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='pie',autopct = '%100.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='pie',autopct = '%1.1f%%')      #1.1 is for ki vo value chart k centre mein rahegi
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Numerical data

# %%
#histogram
sns.histplot(x=df['Age'],bins=20,color='yellow')     #this 20 is for the width of a particular bar
plt.title('Distribution of Age')
plt.show()

# %%
#distplot
sns.histplot(x=df['Age'],kde=True,stat ='density')  #kernel density estimator
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(x=df['Age'],fill = True, color = 'orange')    #column name bhi change kar sakte hai age ki jagah kuch or
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot
# Out:
# <function seaborn.categorical.boxplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, fill=True, dodge='auto', width=0.8, gap=0, whis=1.5, linecolor='auto', linewidth=None, fliersize=None, hue_norm=None, native_scale=False, log_scale=None, formatter=None, legend='auto', ax=None, **kwargs)>

# %%
# box plot
sns.boxplot(x=df['Fare'])    #these circles in the graph are the outliers
# Out:
# <Axes: xlabel='Fare'>

# %%
df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
sns.boxplot(df['Age'])    #the black line in blue bar is median, circles are old age
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# np.float64(0.42)

# %%
df['Age'].max()
# Out:
# np.float64(80.0)

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)

# %% [markdown]
# # EDA-BA-MA

# %%
tips = sns.load_dataset('tips')
titanic = pd.read_csv('train.csv')
flights = sns.load_dataset('flights')

# %% [markdown]
# # Scatter plot (Numeric- Numeric)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x=tips['total_bill'], y=tips['tip'], hue = tips['sex'], style = tips['smoker'], size= tips['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# barplot is useful for showing the average value of a numerical variable across different categories of a categorical variable
sns.barplot(x=titanic['Pclass'], y=titanic['Age'], hue = titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
male_passenger = titanic[titanic['Sex'] == 'male']
male_passenger['Age'].mean()
# Out:
# np.float64(30.72664459161148)

# %%
female_passenger = titanic[titanic['Sex'] == 'female']
female_passenger['Age'].mean()
# Out:
# np.float64(27.915708812260537)

# %%
p1 = titanic[(titanic['Pclass'] == 1 ) & (titanic['Sex'] =='female')]
print( f' we have {p1.shape[0]} female passenger in Pclass1')    #direct p1 print karne se nahi aaega answer, shape print karna padega saath mein
# Out:
#  we have 94 female passenger in Pclass1

# %% [markdown]
# # Boxplot (Ctegorical - Numerical)

# %%
sns.boxplot(x=titanic['Sex'], y=titanic['Age'], hue = titanic['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # histplot (Categorical - Numerical)

# %%
sns.histplot(x=titanic[titanic['Survived']==0]['Age'], kde=True, stat='density')
sns.histplot(x=titanic[titanic['Survived']==1]['Age'], kde=True, stat='density')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(x=titanic[titanic['Survived'] == 0]['Age'])
sns.kdeplot(x=titanic[titanic['Survived'] == 1]['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # Heatmap (Categorical- Categorical)

# %%
titanic.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
pd.crosstab(titanic['Pclass'], titanic['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'], titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
(titanic.groupby('Sex')['Survived'].mean()*100).plot(kind = 'pie', autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='Survived'>

# %% [markdown]
# # Clustermap (categorical-  categorical)

# %%
pd.crosstab(titanic['SibSp'], titanic['Survived'])
# Out:
# Survived    0    1
# SibSp
# 0         398  210
# 1          97  112
# 2          15   13
# 3          12    4
# 4          15    3
# 5           5    0
# 8           7    0

# %%
sns.clustermap(pd.crosstab(titanic['SibSp'], titanic['Survived']))

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(data=iris)

# %% [markdown]
# # Lineplot(numeric - Numeric)

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
new_df = flights.groupby('year')['passengers'].sum().reset_index()

# %%
new_df
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
sns.lineplot(x = new_df['year'], y=new_df['passengers'])      #this plotting is on the sum
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
pv = flights.pivot_table(values = 'passengers', index = 'month', columns = 'year')
# Out:
# /var/folders/pr/fhbf6nxn165_2v51jljjyhlm0000gn/T/ipykernel_32323/2026163460.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pv = flights.pivot_table(values = 'passengers', index = 'month', columns = 'year')

# %%
pv
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...

# %%
sns.heatmap(data=pv)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(data=pv)

# %%
print((titanic[titanic['Survived']==0]['Age'].mean()))
print((titanic[titanic['Survived'] == 1]['Age'].mean()))
# Out:
# 30.62617924528302
# 28.343689655172415

# %%
titanic.groupby('Sex')['Age'].mean().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
pd.crosstab(titanic['Pclass'],titanic['Survived']).plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='species'>

# %%
sns.lineplot(x=flights['year'],y=flights['passengers'])
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
py = flights.groupby('year')['passengers'].sum()

# %%
sns.lineplot(py)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
setosa_df = iris[iris['species'] == 'setosa'][['sepal_length', 'sepal_width']]
virginica_df = iris[iris['species'] == 'virginica'][['sepal_length', 'sepal_width']]

# %%
setosa_df.head()
# Out:
#    sepal_length  sepal_width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2
# 3           4.6          3.1
# 4           5.0          3.6

# %%
virginica_df.head()
# Out:
#      sepal_length  sepal_width
# 100           6.3          3.3
# 101           5.8          2.7
# 102           7.1          3.0
# 103           6.3          2.9
# 104           6.5          3.0

# %%
sns.scatterplot(x=setosa_df['sepal_length'],y=setosa_df['sepal_width'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x=iris['sepal_length'],y=iris['sepal_width'],hue = iris['species'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>
