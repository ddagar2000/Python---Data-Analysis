# %%
import pyodbc

conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=LAPTOP=O3ECL7BM;'  # use your actual server name from sql
    'DATABASE=emp5;'   #here instead of emp5 you need to take any database you want to load
    'Trusted_Connection=yes;'
)

cursor = conn.cursor()   #.cursor will allow all the commands

# run a quesry
cursor.execute("SELECT * from (tablename from that databse)")

#fetch and display results
rows = cursor.fetchall()
for row in rows:
    print(row)


conn.close()    #### this is optional, if want to use this connection further then don't write it

# %%
import pyodbc

conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=LAPTOP=O3ECL7BM;'  # use your actual server name from sql
    'DATABASE=emp5;'   #here instead of emp5 you need to take any database you want to load
    'Trusted_Connection=yes;'
)

cursor = conn.cursor()   #.cursor will allow all the commands

# run a quesry
cursor.execute("SELECT * from (tablename from that databse)")

# get column names
columns = [column[0] for column in cursor.description]

# fetch all rows
rows = cursor.fetchall()

#print column names
print(" | ".join(str(cell) for cell in row))

#print each row
for row in rows:
    print(" | ".join (str(cell) for cell in row))

# close the connection
con.close()

# %% [markdown]
# ### connection to pandas

# %%
import pyodbc
import pandas as pd

conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=LAPTOP=O3ECL7BM;'  # use your actual server name from sql
    'DATABASE=emp5;'   #here instead of emp5 you need to take any database you want to load
    'Trusted_Connection=yes;'
)

#run query and load results into dataframe
query = "SELECT * from (table name)"
df = pd.read_sql(query,conn)

#close connection
conn.close()


#show the dataframe
print(df)

# %%
#adding multiple data

import pyodbc

#connect to sql server

conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=LAPTOP=O3ECL7BM;'  # use your actual server name from sql
    'DATABASE=emp5;'   #here instead of emp5 you need to take any database you want to load
    'Trusted_Connection=yes;'
)

cursor = conn.cursor()

#list of students to insert
students = [
    (9, 'sam', 'sharma', 'HR'),
    (10, 'alex', 'sharma', 'IT'),
    (11, 'rajat', 'sharma', 'DM'),
    (12, 'yash', 'sharma', 'HR'),

]

#insert query matching your table's column names
insert_query = "Insert INTO Employees_US(EmployeeID, FirstName, LastName, Department)  VALUES (?,?,?,?)"

#execute multiple inserts
cursor.executemany(insert_query, students)

#commit changes
conn.commit()

#optional: comfirm inserted data
cursor.execute("SELECT * FROM Employees_US")
for row in cursor.fetchall():
    print(now)


#close connection
conn.close()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pyodbc
#       2 import pandas as pd
#       4 conn = pyodbc.connect(
#       5     'DRIVER={ODBC Driver 17 for SQL Server};'
#       6     'SERVER=LAPTOP=O3ECL7BM;'  # use your actual server name from sql
#       7     'DATABASE=emp5;'   #here instead of emp5 you need to take any database you want to load
#       8     'Trusted_Connection=yes;'
#       9 )
#
# ImportError: dlopen(/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pyodbc.cpython-313-darwin.so, 0x0002): Library not loaded: /opt/homebrew/opt/unixodbc/lib/libodbc.2.dylib
#   Referenced from: <3995BB12-62B9-3D02-8B17-B2B5B5630B8F> /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pyodbc.cpython-313-darwin.so
# ...

# %%
import pyodbc
import pandas as pd

#connect to sql server

conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=LAPTOP=O3ECL7BM;'  # use your actual server name from sql
    'DATABASE=emp5;'   #here instead of emp5 you need to take any database you want to load
    'Trusted_Connection=yes;'
)

# query the students table
df = pd.read_sql("SELECT * FROM [order]", conn)

# close the connection
conn.close()

# show the table
print(df)
